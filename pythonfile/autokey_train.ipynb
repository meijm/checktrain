# %%
import urllib.request
page = urllib.request.urlopen('https://www.12306.cn/index/')
print(page.read())
# Out:
# b'<!DOCTYPE html>\r\n<html lang="zh-CN">\r\n\r\n<head>\r\n  <meta charset="utf-8">\r\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n  <title>\xe4\xb8\xad\xe5\x9b\xbd\xe9\x93\x81\xe8\xb7\xaf12306\xe7\xbd\x91\xe7\xab\x99</title>\r\n  <script>\r\n    window.startTime = new Date().getTime(); //"window.onload\xe5\xa4\x96\xe5\xbc\x80\xe5\xa7\x8b\xe6\x97\xb6\xe9\x97\xb4:",window.startTime\r\n  </script>\r\n  <link rel="shortcut icon" href="images/favicon.ico" type="image/x-icon" />\r\n  <!-- <link href="./css/index.css" rel="stylesheet">\r\n  <link href="./css/global.css" rel="stylesheet">\r\n  <link href="./css/public.css" rel="stylesheet"> -->\r\n  <link href="./fonts/iconfont.css" rel="stylesheet">\r\n  <!-- \xe6\x97\xa5\xe6\x9c\x9f\xe5\x9f\x8e\xe5\xb8\x82\xe6\x8e\xa7\xe4\xbb\xb6 -->\r\n  <!-- <link href="./css/common/calendarNew.css" rel="stylesheet">\r\n  <link href="./css/common/table.css" rel="stylesheet">\r\n  <link href="./css/common/station.css" rel="styleshe
# ...

# %%
import requests
response = requests.get('https://www.12306.cn/index/')
print (response.status_code)
print (response.content)
# Out:
# 200
# ...

# %%
from bs4 import BeautifulSoup
html_doc=response.content
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    中国铁路12306网站
#   </title>
#   <script>
#    window.startTime = new Date().getTime(); //"window.onload外开始时间:",window.startTime
#   </script>
#   <link href="images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!-- <link href="./css/index.css" rel="stylesheet">
#   <link href="./css/global.css" rel="stylesheet">
#   <link href="./css/public.css" rel="stylesheet"> -->
#   <link href="./fonts/iconfont.css" rel="stylesheet"/>
#   <!-- 日期城市控件 -->
#   <!-- <link href="./css/common/calendarNew.css" rel="stylesheet">
#   <link href="./css/common/table.css" rel="stylesheet">
#   <link href="./css/common/station.css" rel="stylesheet">
#   <link rel="stylesheet" href="./css/main.css"> -->
#   <link href="./css/index_y_v50001.css" rel="stylesheet"/>
#  </head>
#  <style>
#   .typeahead li {
#     width: 265px;
# ...

# %%
print(soup.get_text())
# Out:
# 中国铁路12306网站
#
#     window.startTime = new Date().getTime(); //"window.onload外开始时间:",window.startTime
#
#
#
#
#
#
#
#
#
#   .typeahead li {
#     width: 265px;
#     padding-left: 10px;
#   }
#
#   a:hover {
#     color: #000;
#   }
#
#
#
#
#
#
#
#
#
#
# 中国铁路12306
#
#
#
#
#
#
#
#
#
# 关闭
#
#
#
#
# 清除
# 搜索历史
#
#
#
#
#
#
#
#
#
#
# 无障碍
#
# |
#
# 爱心版
#
# |
#
#
#                 English
#
#
#
#
# 简体中文
#
#
# English
#
#
#
# |
#
# 我的12306
#
#
#
#
# 火车票订单
#
#
# 候补订单
#
#
# 计次•定期票订单
#
#
# 约号订单
#
#
# 本人车票
#
#
#
# 我的餐饮•特产
#
#
# 我的保险
#
#
# 我的会员
#
#
#
# 查看个人信息
#
#
# 账户安全
#
#
#
# 乘车人
#
#
# 地址管理
#
#
#
# 温馨服务查询
#
#
#
# |
#
# 登录注册
#
#
#               您好，
#  | 退出
#
#
#
#
#
#
#
#
#
# 首页
#
#
# 车票
#
#
#
#
# 购买
#
#
# 单程
#
#
# 往返
#
#
# 中转换乘
#
#
# 计次•定期票
#
#
#
#
#
# 变更
#
#
# 退票
#
#
# 改签
#
#
# 变更到站
#
#
#
#
#
# 更多
#
#
# 中铁银通卡
#
#
# 广九直通车
#
#
# 市郊快速铁路
#
#
# 国际列车
#
#
#
#
#
#
# 团购服务
#
#
#
#
#
#
# 务工人员
#
#
# 学生团体
#
#
#
#
#
#
# 会员服务
#
#
#
#
#
#
# 会员管理
#
#
# 积分账户
#
#
# 积分兑换
#
#
# 会员专享
#
#
# 会员中心
#
#
#
#
#
#
# 站车服务
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

options = ChromeOptions()
chrome_options.add_argument("--headless=new")
driver = webdriver.Chrome(r'C:\Users\Administrator\Documents\meijmPy\chromedriver.exe')

driver.get("https://www.12306.cn/index/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7751377104c2> in <module>
#       4
#       5 driver = webdriver.Chrome(r'C:\Users\Administrator\Documents\meijmPy\chromedriver.exe')
# ----> 6 driver.add_argument('ignore-certificate-errors')
#       7 driver.get("https://www.12306.cn/index/")
#
# AttributeError: 'WebDriver' object has no attribute 'add_argument'

# %%
element=driver.find_element(By.ID, "fromStationText")

# %%
element.click()

# %%
element.send_keys("高安")

# %%
element.send_keys(Keys.ENTER)

# %%
element2=driver.find_element(By.ID, "toStationText")

# %%
element2.click()

# %%
element2.send_keys("上海")

# %%
element2.send_keys(Keys.ENTER)

# %%
element3=driver.find_element(By.ID, "search_one")

# %%
element3.send_keys(Keys.ENTER)
